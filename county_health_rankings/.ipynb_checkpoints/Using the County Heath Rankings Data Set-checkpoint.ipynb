# %%
import pandas as pd
import numpy as np
import geopandas

# %%
url = 'https://raw.githubusercontent.com/thomaspingel/geodata/master/county_health_rankings/chr_2016.csv'
chr_df = pd.read_csv(url,dtype={'FIPS':str})
chr_df.head()
# Out:
#     FIPS    State   County  Premature death - # Deaths  \
# 0  01001  Alabama  Autauga                       809.0
# 1  01003  Alabama  Baldwin                      2506.0
# 2  01005  Alabama  Barbour                       410.0
# 3  01007  Alabama     Bibb                       414.0
# 4  01009  Alabama   Blount                       876.0
#
#    Premature death - Years of Potential Life Lost Rate  \
# 0                                             9215.1
# 1                                             7454.6
# 2                                             8499.9
# 3                                            11007.7
# 4                                             8655.9
#
#    Poor or fair health - % Fair/Poor  \
# 0                               19.4
# 1                               16.0
# 2                               25.7
# 3                               22.0
# 4                               20.7
#
#    Poor physical health days - Physically Unhealthy Days  \
# 0                                                4.4
# 1                                                4.1
# 2                                                4.9
# 3                                                4.8
# 4                                                4.6
#
#    Poor mental health days - Mentally Unhealthy Days  \
# 0                                                4.3
# 1                                                4.2
# 2                                                4.7
# 3                                                4.6
# 4                                                4.5
#
#   Low birthweight - Unreliable  Low birthweight - # Low Birthweight Births  \
# 0                          NaN                                       407.0
# 1                          NaN                                      1300.0
# 2                          NaN                                       272.0
# 3                          NaN                                       221.0
# 4                          NaN                                       364.0
#
#    ...  Demographics - % Native Hawaiian/Other Pacific Islander  \
# 0  ...                                           0.101092
# 1  ...                                           0.063964
# 2  ...                                           0.174806
# 3  ...                                           0.128855
# 4  ...                                           0.114347
#
#    Demographics - # Hispanic  Demographics - % Hispanic  \
# 0                     1514.0                   2.733099
# 1                     9130.0                   4.562468
# 2                     1219.0                   4.533790
# 3                      474.0                   2.106105
# 4                     5042.0                   8.735425
#
#    Demographics - # Non-Hispanic White  Demographics - % Non-Hispanic White  \
# 0                              41877.0                            75.597076
# 1                             166093.0                            83.000435
# 2                              12525.0                            46.583851
# 3                              16772.0                            74.522350
# 4                              50652.0                            87.756198
#
#    Demographics - # Not Proficient in English  \
# 0                                       249.0
# 1                                      2571.0
# 2                                       549.0
# 3                                       112.0
# 4                                       954.0
#
#    Demographics - % Not Proficient in English  Demographics - % Female  \
# 0                                    0.481429                51.362036
# 1                                    1.429898                51.228568
# 2                                    2.150664                46.613605
# 3                                    0.521100                45.934417
# 4                                    1.765032                50.531021
#
#    Demographics - # Rural  Demographics - % Rural
# 0                 22921.0               42.002162
# 1                 77060.0               42.279099
# 2                 18613.0               67.789635
# 3                 15663.0               68.352607
# 4                 51562.0               89.951502
#
# [5 rows x 132 columns]

# %%
url = 'https://raw.githubusercontent.com/thomaspingel/geodata/master/election/county_election_data_2000-2016.csv'
election_df = pd.read_csv(url,dtype={'FIPS':str})
election_df = election_df.loc[:,['FIPS','gop_minus_dem_prc_2016']]
election_df.head()
# Out:
#     FIPS  gop_minus_dem_prc_2016
# 0  01001                   49.00
# 1  01003                   57.16
# 2  01005                    5.57
# 3  01007                   55.15
# 4  01009                   80.90

# %%
url = 'https://raw.githubusercontent.com/thomaspingel/geodata/master/cartographic_boundary_files/cb_2016_us_county_20m.geojson'
counties_df = geopandas.read_file(url)
counties_df.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID        NAME LSAD  \
# 0      39      131  01074078  0500000US39131  39131        Pike   06
# 1      46      003  01266983  0500000US46003  46003      Aurora   06
# 2      55      035  01581077  0500000US55035  55035  Eau Claire   06
# 3      72      145  01804553  0500000US72145  72145   Vega Baja   13
# 4      48      259  01383915  0500000US48259  48259     Kendall   06
#
#         ALAND    AWATER                                           geometry
# 0  1140324458   9567612  (POLYGON ((-83.353531 39.197585, -82.785891000...
# 1  1834813753  11201379  (POLYGON ((-98.807771 43.935223, -98.331508 43...
# 2  1652211310  18848512  (POLYGON ((-91.65045499999999 44.855951, -90.9...
# 3   118766803  57805868  (POLYGON ((-66.448989 18.387214, -66.438950007...
# 4  1715747531   1496797  (POLYGON ((-98.920147 30.13829, -98.587897 30....
